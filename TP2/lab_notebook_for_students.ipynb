# %% [markdown]
# # CSC 8614 - Language Models
# ## CI2 - Fine-tuning a language model for text classification
#
# In this TP, you will work on fine-tuning a language model to move from text generation to text classification, specifically working on Spam Detection.
#
# The exercise (and code) has been adapted from the book _Build a Large Language Model (From Scratch)_, by Sebastian Raschka, and its [official github repository](https://github.com/rasbt/LLMs-from-scratch).
#
# This TP will be done in this notebook, and requires some additional files (available from the course website). You will have to fill the missing portions of code, and perform some additional experiments by testing different parameters.
#
# Working on this TP:
# - The easiest way is probably to work directly on the notebook, using jupyter notebook or visual studio code. An alternative is also to use Google colab.
# - You should be able to run everything on your machine, but you can connect to the GPUs if needed.
#
# Some files are required, and are available on the course website:
# - `requirements.txt`
# - `gpt_utils.py`
#
#
# ## About the report
# You will have to return this notebook (completed), as well as a mini-report (`TP2/rapport.md`).
#
# The notebook and report shall be submitted via a GitHub repository, similarly to what you did for the first session (remember to use a different folder: `TP2`).
# For the notebook, it is sufficient to complete the code and submit the final version.
#
# For the mini-report, you have to answer the questions asked in this notebook, and discuss some of your findings as requested.
# As for the first session:
# - "Vous devez y mettre : réponses courtes, résultats observés (copie de sorties), captures d’écran demandées, et une courte interprétation."
# - "Ne collez pas des pages entières : soyez concis et sélectionnez les éléments pertinents."
#
# Reproducibility:
# - fix a random seed and write it in the report
# - indicate in the report the specific python version OS, and the library versions.

# %% [markdown]
# **Question 1**: Dans `TP1/rapport.md`, ajoutez immédiatement un court en-tête (quelques lignes) contenant : (i) votre nom/prénom, (ii) la commande d’installation/activation d’environnement utilisée, (iii) les versions (Python + bibliothèques principales).
#
# Ajoutez ensuite au fil du TP des sections/titres à votre convenance, tant que l’on peut retrouver clairement vos réponses et vos preuves d’exécution.

# %%
# [Instructor code: install requirements]
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch==2.9.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: tiktoken==0.12.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: tqdm==4.67.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: pandas==2.3.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: matplotlib==3.10.8 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (3.10.8)
# Requirement already satisfied: tensorflow==2.20.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: jupyterlab==4.5.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (4.5.1)
# Requirement already satisfied: filelock in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from torch==2.9.1->-r requirements.txt (line 1)) (2026.1.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tiktoken==0.12.0->-r requirements.txt (line 2)) (2026.1.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tiktoken==0.12.0->-r requirements.txt (line 2)) (2.32.5)
# Requirement already satisfied: numpy>=1.23.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from pandas==2.3.3->-r requirements.txt (line 4)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from matplotlib==3.10.8->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (6.33.4)
# Requirement already satisfied: setuptools in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (80.10.1)
# Requirement already satisfied: six>=1.12.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.13.1)
# Requirement already satisfied: h5py>=3.11.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorflow==2.20.0->-r requirements.txt (line 6)) (0.5.4)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: jupyter-core in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.5.4)
# Requirement already satisfied: traitlets in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: anyio in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.12.1)
# Requirement already satisfied: certifi in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: idna in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.26.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken==0.12.0->-r requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken==0.12.0->-r requirements.txt (line 2)) (2.6.3)
# Requirement already satisfied: markdown>=2.6.8 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (3.1.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.46.2)
# Requirement already satisfied: appnope>=0.1.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (9.9.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (7.2.1)
# Requirement already satisfied: decorator>=4.3.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jinja2->torch==2.9.1->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-core->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (25.10.0)
# Requirement already satisfied: rich in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (14.2.0)
# Requirement already satisfied: namex in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.1.0)
# Requirement already satisfied: optree in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.18.0)
# Requirement already satisfied: beautifulsoup4 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch==2.9.1->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/yohan/Documents/3Aschool/modelesDeLangage/.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow==2.20.0->-r requirements.txt (line 6)) (0.1.2)

# %%
import random, numpy as np, torch
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## Preparing the model

# %%
# --- [INSTRUCTOR CODE: load the model weights into memory] ---
import torch
import tiktoken
from gpt_utils import GPTModel, download_and_load_gpt2, load_weights_into_gpt

# Download the model weights (124M param version) / This function (which we put in gpt_utils) handles the downloading
settings, params = download_and_load_gpt2(model_size="124M", models_dir="gpt2_weights")
print("Weights downloaded and loaded into memory.")
# Out:
# File already exists and is up-to-date: gpt2_weights/124M/checkpoint
# File already exists and is up-to-date: gpt2_weights/124M/encoder.json
# File already exists and is up-to-date: gpt2_weights/124M/hparams.json
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.index
# File already exists and is up-to-date: gpt2_weights/124M/model.ckpt.meta
# File already exists and is up-to-date: gpt2_weights/124M/vocab.bpe
# Weights downloaded and loaded into memory.

# %% [markdown]
# The `settings` obtained with `download_and_load_gpt2` are the GPT-2 weights made publicly available by OpenAI.
#
# **Question 2**: What type is the object `setting`, and what is its structure (e.g. if it is a list, its length; if a dictionary, its keys, etc.)?
#
# **Question 3**: What type is the object `params`, and what is its structure?

# %%
# Analyse settings
print("settings :", type(settings))
if isinstance(settings, dict):
    print("keys(settings) =", list(settings.keys()))
    for k, v in settings.items():
        print(f"  {k} -> {v}")
else:
    print("len(settings) =", len(settings))


# Analyse params
print("\nparams :", type(params))
if isinstance(params, dict):
    print("keys(params) =", list(params.keys()))


    for k, v in params.items():
        if isinstance(v, dict):
            print(f"  {k} -> dict, keys={list(v.keys())}")
        elif isinstance(v, (list, tuple)):
            print(f"  {k} -> {type(v).__name__}, len={len(v)}")
            if len(v) > 0:
                print(f"     [0] type={type(v[0])}")
        else:
            try:
                print(f"  {k} -> {type(v).__name__}, shape={tuple(v.shape)}")
            except Exception:
                print(f"  {k} -> {type(v).__name__}")
else:
    print("len(params) =", len(params))
# Out:
# settings : <class 'dict'>
# keys(settings) = ['n_vocab', 'n_ctx', 'n_embd', 'n_head', 'n_layer']
#   n_vocab -> 50257
#   n_ctx -> 1024
#   n_embd -> 768
#   n_head -> 12
#   n_layer -> 12
#
# params : <class 'dict'>
# keys(params) = ['blocks', 'b', 'g', 'wpe', 'wte']
#   blocks -> list, len=12
#      [0] type=<class 'dict'>
#   b -> ndarray, shape=(768,)
#   g -> ndarray, shape=(768,)
#   wpe -> ndarray, shape=(1024, 768)
#   wte -> ndarray, shape=(50257, 768)

# %% [markdown]
# Look at the `GPTModel` in the file `gpt_utils.py`. In the `__init__` method, we have to pass a config (parameter `cfg`).
#
# **Question 4:**
# Analyse the `__init__` method, and check what is the required structure for the `cfg` parameter. Is the `settings` variable we have obtained in the right format? If not, perform the mapping to convert the variable `setting` into a variable `model_config` with the right structure.

# %%
# Configure the model, mapping OpenAI specific keys to our model's keys (if needed)
model_config = {
    "vocab_size": settings.get("vocab_size", settings["n_vocab"]),
    "context_length": settings.get("context_length", settings["n_ctx"]),
    "emb_dim": settings.get("emb_dim", settings["n_embd"]),
    "n_heads": settings.get("n_heads", settings["n_head"]),
    "n_layers": settings.get("n_layers", settings["n_layer"]),
    "drop_rate": 0.1,
    "qkv_bias": True,
}

# %%
model = GPTModel(model_config)

# Load the pre-trained weights
load_weights_into_gpt(model, params)
model.eval() 

print("GPT-2 Model Loaded and Configured successfully!")
# Out:
# GPT-2 Model Loaded and Configured successfully!

# %% [markdown]
# ## Preparing the data
#
# Context from the lecture: The raw data is just text messages.
#
# The model needs numbers (token IDs). We also need to pad the messages so they are all the same length in a batch.
#
# We will use a `SpamDataset` class (provided below) to tokenize the text.

# %%
# --- [INSTRUCTOR CODE: Run this cell to define the Dataset Class] ---
from torch.utils.data import Dataset
import pandas as pd
import urllib.request
import zipfile
import os

class SpamDataset(Dataset):
    def __init__(self, csv_file, tokenizer, max_length=120, pad_token_id=50256):
        self.data = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.pad_token_id = pad_token_id
        # Encode labels: "spam" -> 1, "ham" -> 0
        self.data["label_encoded"] = self.data["Label"].map({"spam": 1, "ham": 0})

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        text = self.data.iloc[idx]["Text"]
        label = self.data.iloc[idx]["label_encoded"]
        # Tokenize
        encoded = self.tokenizer.encode(text, allowed_special={'<|endoftext|>'})       
        # Truncate if too long
        encoded = encoded[:self.max_length]
        # Pad if too short
        pad_len = self.max_length - len(encoded)
        encoded += [self.pad_token_id] * pad_len
        return torch.tensor(encoded, dtype=torch.long), torch.tensor(label, dtype=torch.long)

# Download the dataset zip file
url = "https://archive.ics.uci.edu/static/public/228/sms+spam+collection.zip"
zip_path = "sms_spam_collection.zip"
extract_path = "sms_spam_collection"
data_file_path = os.path.join(extract_path, "SMSSpamCollection")
if not os.path.exists(zip_path):
    print("Downloading dataset...")
    urllib.request.urlretrieve(url, zip_path)
    print("Download complete.")
# Unzip
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(extract_path)
# Read the TSV file
df = pd.read_csv(
    data_file_path, 
    sep="\t", 
    header=None, 
    names=["Label", "Text"]
)
print(f"Total samples loaded: {len(df)}")

# 4. Create Train/Test Split (80 train / 20 test)
df = df.sample(frac=1, random_state=123).reset_index(drop=True)
# Split index
split_idx = int(0.8 * len(df))

# TODO: if needed (for performance resons), you can come back here and reduce the size of the training set.
train_df = df.iloc[:split_idx]  # [:2000]  # Readd this to only consider 2000 training samples
test_df = df.iloc[split_idx:]

# Save as CSVs, so the SpamDataset class can read them.
train_df.to_csv("train.csv", index=False)
test_df.to_csv("test.csv", index=False)
print("Created 'train.csv' and 'test.csv' successfully!")
print(f"Train size: {len(train_df)}")
print(f"Test size: {len(test_df)}")
# Out:
# Total samples loaded: 5572
# Created 'train.csv' and 'test.csv' successfully!
# Train size: 4457
# Test size: 1115

# %% [markdown]
# **Question 5.1**: In the cell above, why did we do `df = df.sample(frac=1, random_state=123)` when creating the train/test split?
#
# **Question 5.2**: Analyse the datasets, what is the distribution of the two classes in the train set? Are they balanced or unbalanced? In case they are unbalanced, might this lead to issues for the fine-tuning of the model?

# %%
import pandas as pd

train_df = pd.read_csv("train.csv")

print("Taille train:", len(train_df))
print(train_df["Label"].value_counts())
print(train_df["Label"].value_counts(normalize=True))
# Out:
# Taille train: 4457
# Label
# ham     3860
# spam     597
# Name: count, dtype: int64
# Label
# ham     0.866053
# spam    0.133947
# Name: proportion, dtype: float64

# %% [markdown]
# **Question 6**: Create the dataloaders for training and test.

# %%
# TODO: add any imports which are needed
from torch.utils.data import DataLoader

# Create the Tokenizer
tokenizer = tiktoken.get_encoding("gpt2")

# Instantiate the Dataset
train_dataset = SpamDataset("train.csv", tokenizer)
test_dataset = SpamDataset("test.csv", tokenizer)

# --- TODO: Create DataLoaders ---
# 1. Create a train_loader with batch_size=16 and shuffle=True
g = torch.Generator().manual_seed(42)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, generator=g)
# 2. Create a test_loader with batch_size=16 and shuffle=False
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
# Check your work
for input_batch, target_batch in train_loader:
    print("Input batch shape:", input_batch.shape) # Should be [16, 120] (unless you use batch_size != 16)
    print("Target batch shape:", target_batch.shape) # Should be [16]
    break
# Out:
# Input batch shape: torch.Size([16, 120])
# Target batch shape: torch.Size([16])

# %% [markdown]
# **Question 7**: Looking at the batch size and the training size, how many batches will you have in total? Please report the size of the subsampled training data, you reduce it due to performance constraints.

# %%
import math

train_size = len(train_dataset)
batch_size = train_loader.batch_size
num_batches = math.ceil(train_size / batch_size)

print("train_size:", train_size)
print("batch_size:", batch_size)
print("num_batches:", num_batches)
print("len(train_loader):", len(train_loader))
# Out:
# train_size: 4457
# batch_size: 16
# num_batches: 279
# len(train_loader): 279

# %% [markdown]
# ## Fine-tuning

# %% [markdown]
# **Context**: GPT-2 was trained to predict the next word (output size ~50,000). We want to predict binary classes (output size 2), so we must replace the final layer.

# %% [markdown]
# **Question 8**:
#
# **8.1**: In the cell below, define the number of output classes (`num_classes`) for the new spam detection task.
#
# **8.2**: Also, pring the original and updated output heads (hint: `out_head` from `GPTModel`)
#
# **8.3**: Why do we freeze the internal layers with `param.requires_grad = False`?

# %%
# Freeze the internal layers
for param in model.parameters():
    param.requires_grad = False

print(f"Original output head: {model.out_head}") # TODO: YOUR CODE HERE

num_classes = 2
model.out_head = torch.nn.Linear(768, num_classes)
# Hint: The input size of the last layer in GPT-2 small is 768.

# Enable gradient calculation ONLY for the new head and the final LayerNorm
for param in model.out_head.parameters():
    param.requires_grad = True
for param in model.trf_blocks[-1].norm2.parameters():
    param.requires_grad = True

print(f"New output head: {model.out_head}") # TODO: YOUR CODE HERE
# Out:
# Original output head: Linear(in_features=768, out_features=50257, bias=False)
# New output head: Linear(in_features=768, out_features=2, bias=True)

# %% [markdown]
# You now have to **finalise the code for the training loop** (see individual steps below).
#
# In the first cell below you can find the code to move the model to GPU (if available), define the optimizer, and calculate the accuracy. The following cell contains the code for the training (fine-tuning) loop.
#
# You will have to complete the code of the training loop, by answering the following questions:
#
# **Question 9.1**: Reset the gradients of the `optimizer` ([hint](https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.zero_grad.html)).
#
# **Question 9.2**: Compute cross-entropy loss ([hint](https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html)).
#
# **Question 9.3**: Add code for the backward pass, to compute the gradient ([hint](https://docs.pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html))
#
# **Question 9.4**: Add code for the optimizer step, to update the weights ([hint](https://docs.pytorch.org/docs/stable/generated/torch.optim.Optimizer.step.html))
#
# **Question 9.5**: Add code to calculate the accuracy on train and test (hint: you can use the `calc_accuracy` method).
#
# **Note about the speed**: On my laptop's CPU 1 epoch with the full training dataset (~4400 samples, batch_size=16) took ~20 minutes; 1 epoch with a train set of 2000 samples (batch_size=16) took ~12 minutes.
#
# To iterate more quickly, you could:
# - i) set `num_epochs = 1` (but only at the beginning), just to make sure that the code is working;
# - ii) increase batch_size to 32 or 64 (but careful with possible memory issues).
# - iii) reduce the size of the training dataset, by going back to the *Preparing the data* section, and changing the line `train_df = df.iloc[:split_idx]` to `train_df = df.iloc[:split_idx][:2000]` or similar. Be careful that if you reduce the training data too much, the model will not have enough data for fine-tuning.
# - Use a GPU; it would be much quicker (few minutes on the whole training data).

# %%
# [--- INSTRUCTOR CODE ---]

# Move model to GPU if available
device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
model.to(device)

# Measure imbalance
count_ham = len(train_df[train_df['Label']=='ham'])
count_spam = len(train_df[train_df['Label']=='spam'])

# Calculate weight: penalize missing the minority class (Spam) more
# Weight = Count(Majority) / Count(Minority)
pos_weight = count_ham / count_spam  # approx 6.46 (for full training dataset)
class_weights = torch.tensor([1.0, pos_weight]).to(device)
print(f"Using class weights: {class_weights}")

# Define Optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5, weight_decay=0.1)

# Calculate Accuracy Helper Function
def calc_accuracy(loader, model, device):
    correct, total = 0, 0
    # Track spam specifically
    spam_correct, spam_total = 0, 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            logits = model(inputs)[:, -1, :]
            predicted = torch.argmax(logits, dim=-1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            # Filter for Spam (Label 1)
            spam_mask = (labels == 1)
            spam_total += spam_mask.sum().item()
            spam_correct += (predicted[spam_mask] == labels[spam_mask]).sum().item()
    # Avoid division by zero
    spam_acc = spam_correct / spam_total if spam_total > 0 else 0.0
    global_acc = correct / total
    return global_acc, spam_acc
# Out:
# Using class weights: tensor([1.0000, 6.4657], device='mps:0')

# %%
# TODO: Add your code where needed in this cell

import torch.nn.functional as F

num_epochs = 3  # TODO: (Optional questions: update this to see how the fine-tuning changes with more epochs)

for epoch in range(num_epochs):
    model.train()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 9.1. Reset Gradients (of the `optimizer`)
        optimizer.zero_grad(set_to_none=True)

        # Forward Pass. The model outputs (batch, seq_len, vocab_size). 
        # We only want the prediction for the LAST token in the sequence.
        logits = model(inputs)[:, -1, :]

        # 9.2. Calculate the cross entropy loss
        loss = F.cross_entropy(logits, targets, weight=class_weights)

        # 9.3. Backward Pass
        loss.backward()
        # 9.4 Optimizer Step
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # 9.5 Add code to calculate the accuracy on train and test
    train_acc, train_spam_acc = calc_accuracy(train_loader, model, device)
    test_acc, test_spam_acc = calc_accuracy(test_loader, model, device)
    print(f"Epoch {epoch+1}: Train Acc: {train_acc*100:.2f}% (Spam: {train_spam_acc*100:.2f}%) | Test Acc: {test_acc*100:.2f}% (Spam: {test_spam_acc*100:.2f}%)")
# Out:
# Epoch 1, Batch 0, Loss: 1.6847
# Epoch 1, Batch 10, Loss: 1.0761
# Epoch 1, Batch 20, Loss: 1.4734
# Epoch 1, Batch 30, Loss: 1.0486
# Epoch 1, Batch 40, Loss: 1.1310
# Epoch 1, Batch 50, Loss: 0.8639
# Epoch 1, Batch 60, Loss: 0.6575
# Epoch 1, Batch 70, Loss: 0.7356
# Epoch 1, Batch 80, Loss: 0.6321
# Epoch 1, Batch 90, Loss: 0.8362
# Epoch 1, Batch 100, Loss: 0.6117
# Epoch 1, Batch 110, Loss: 0.7376
# Epoch 1, Batch 120, Loss: 0.6255
# Epoch 1, Batch 130, Loss: 0.6536
# Epoch 1, Batch 140, Loss: 0.8943
# Epoch 3, Batch 170, Loss: 0.5486
# Epoch 3, Batch 180, Loss: 0.5624
# Epoch 3, Batch 190, Loss: 0.6869
# Epoch 3, Batch 200, Loss: 0.5993
# Epoch 3, Batch 210, Loss: 0.6386
# Epoch 3, Batch 220, Loss: 0.5932
# Epoch 3, Batch 230, Loss: 0.4802
# Epoch 3, Batch 240, Loss: 0.6616
# Epoch 3, Batch 250, Loss: 0.7121
# Epoch 3, Batch 260, Loss: 0.6868
# Epoch 3, Batch 270, Loss: 0.6722
# Epoch 3: Train Acc: 61.72% (Spam: 97.82%) | Test Acc: 63.32% (Spam: 98.00%)

# %% [markdown]
# **Question 10**:
#
# Now run the cell above. You should see how the training loss changes after each batch (and epoch).
# Describe thie trend: what do you see, is the model learning?
#
# **Question 11 (optional)**: Change the number of epochs and/or the learning rate and/or the size of the training data, and investigate how the loss/accuracy of the model changes. You can do this editing and re-running the cells above, or creating new cells below.

# %% [markdown]
# ### test - plus d'epochs

# %%
# TODO: Add your code where needed in this cell

import torch.nn.functional as F

num_epochs = 6  # TODO: (Optional questions: update this to see how the fine-tuning changes with more epochs)

for epoch in range(num_epochs):
    model.train()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 9.1. Reset Gradients (of the `optimizer`)
        optimizer.zero_grad(set_to_none=True)

        # Forward Pass. The model outputs (batch, seq_len, vocab_size). 
        # We only want the prediction for the LAST token in the sequence.
        logits = model(inputs)[:, -1, :]

        # 9.2. Calculate the cross entropy loss
        loss = F.cross_entropy(logits, targets, weight=class_weights)

        # 9.3. Backward Pass
        loss.backward()
        # 9.4 Optimizer Step
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # 9.5 Add code to calculate the accuracy on train and test
    train_acc, train_spam_acc = calc_accuracy(train_loader, model, device)
    test_acc, test_spam_acc = calc_accuracy(test_loader, model, device)
    print(f"Epoch {epoch+1}: Train Acc: {train_acc*100:.2f}% (Spam: {train_spam_acc*100:.2f}%) | Test Acc: {test_acc*100:.2f}% (Spam: {test_spam_acc*100:.2f}%)")
# Out:
# Epoch 1, Batch 0, Loss: 0.7202
# Epoch 1, Batch 10, Loss: 0.5563
# Epoch 1, Batch 20, Loss: 0.6558
# Epoch 1, Batch 30, Loss: 0.8056
# Epoch 1, Batch 40, Loss: 0.5233
# Epoch 1, Batch 50, Loss: 0.5891
# Epoch 1, Batch 60, Loss: 0.5183
# Epoch 1, Batch 70, Loss: 0.5349
# Epoch 1, Batch 80, Loss: 0.8061
# Epoch 1, Batch 90, Loss: 0.7475
# Epoch 1, Batch 100, Loss: 0.6040
# Epoch 1, Batch 110, Loss: 0.8444
# Epoch 1, Batch 120, Loss: 0.7083
# Epoch 1, Batch 130, Loss: 0.5494
# Epoch 1, Batch 140, Loss: 0.6022
# Epoch 1, Batch 150, Loss: 0.6511
# Epoch 1, Batch 160, Loss: 0.6411
# Epoch 1, Batch 170, Loss: 0.5391
# Epoch 5, Batch 210, Loss: 0.5162
# Epoch 5, Batch 220, Loss: 0.6110
# Epoch 5, Batch 230, Loss: 0.4916
# Epoch 5, Batch 240, Loss: 0.5791
# Epoch 5, Batch 250, Loss: 0.6301
# Epoch 5, Batch 260, Loss: 0.5099
# Epoch 5, Batch 270, Loss: 0.5907
# Epoch 5: Train Acc: 80.48% (Spam: 91.12%) | Test Acc: 82.60% (Spam: 94.00%)
# Epoch 6, Batch 0, Loss: 0.6436
# Epoch 6, Batch 10, Loss: 0.4943
# Epoch 6, Batch 20, Loss: 0.5822
# Epoch 6, Batch 30, Loss: 0.4943
# Epoch 6, Batch 40, Loss: 0.4820
# Epoch 6, Batch 50, Loss: 0.6176
# Epoch 6, Batch 60, Loss: 0.6234
# Epoch 6, Batch 70, Loss: 0.7004
# Epoch 6, Batch 80, Loss: 0.6098
# Epoch 6, Batch 90, Loss: 0.5463
# Epoch 6, Batch 100, Loss: 0.5613
# Epoch 6, Batch 110, Loss: 0.5946
# Epoch 6, Batch 120, Loss: 0.6091
# Epoch 6, Batch 130, Loss: 0.4908
# Epoch 6, Batch 140, Loss: 0.6501
# Epoch 6, Batch 150, Loss: 0.5298
# Epoch 6, Batch 160, Loss: 0.5222
# Epoch 6, Batch 170, Loss: 0.7367
# Epoch 6, Batch 180, Loss: 0.5785
# Epoch 6, Batch 190, Loss: 0.5438
# Epoch 6, Batch 200, Loss: 0.5742
# Epoch 6, Batch 210, Loss: 0.5493
# Epoch 6, Batch 220, Loss: 0.4837
# Epoch 6, Batch 230, Loss: 0.6531
# Epoch 6, Batch 240, Loss: 0.5789
# Epoch 6, Batch 250, Loss: 0.6244
# Epoch 6, Batch 260, Loss: 0.5641
# Epoch 6, Batch 270, Loss: 0.5892
# Epoch 6: Train Acc: 70.45% (Spam: 94.64%) | Test Acc: 72.02% (Spam: 96.67%)

# %% [markdown]
# ### test - petit learning rate

# %%
# TODO: Add your code where needed in this cell

import torch.nn.functional as F

num_epochs = 3  # TODO: (Optional questions: update this to see how the fine-tuning changes with more epochs)

for epoch in range(num_epochs):
    model.train()
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 9.1. Reset Gradients (of the `optimizer`)
        optimizer.zero_grad(set_to_none=True)

        # Forward Pass. The model outputs (batch, seq_len, vocab_size). 
        # We only want the prediction for the LAST token in the sequence.
        logits = model(inputs)[:, -1, :]

        # 9.2. Calculate the cross entropy loss
        loss = F.cross_entropy(logits, targets, weight=class_weights)

        # 9.3. Backward Pass
        loss.backward()
        # 9.4 Optimizer Step
        optimizer.step()

        if batch_idx % 10 == 0:
            print(f"Epoch {epoch+1}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    # 9.5 Add code to calculate the accuracy on train and test
    train_acc, train_spam_acc = calc_accuracy(train_loader, model, device)
    test_acc, test_spam_acc = calc_accuracy(test_loader, model, device)
    print(f"Epoch {epoch+1}: Train Acc: {train_acc*100:.2f}% (Spam: {train_spam_acc*100:.2f}%) | Test Acc: {test_acc*100:.2f}% (Spam: {test_spam_acc*100:.2f}%)")
# Epoch 3, Batch 0, Loss: 0.5811
# Epoch 3, Batch 10, Loss: 0.6711
# Epoch 3, Batch 20, Loss: 0.4498
# Epoch 3, Batch 30, Loss: 0.5050
# Epoch 3, Batch 40, Loss: 0.4095
# Epoch 3, Batch 50, Loss: 0.7536
# Epoch 3, Batch 60, Loss: 0.4754
# Epoch 3, Batch 70, Loss: 0.5252
# Epoch 3, Batch 80, Loss: 0.4615
# Epoch 3, Batch 90, Loss: 0.4775
# Epoch 3, Batch 100, Loss: 0.5496
# Epoch 3, Batch 110, Loss: 0.5435
# Epoch 3, Batch 120, Loss: 0.5178
# Epoch 3, Batch 130, Loss: 0.4621
# Epoch 3, Batch 140, Loss: 0.4793
# Epoch 3, Batch 150, Loss: 0.4224
# Epoch 3, Batch 160, Loss: 0.6610
# Epoch 3, Batch 170, Loss: 0.4644
# Epoch 3, Batch 180, Loss: 0.5024
# Epoch 3, Batch 190, Loss: 0.5372
# Epoch 3, Batch 200, Loss: 0.7151
# Epoch 3, Batch 210, Loss: 0.8910
# Epoch 3, Batch 220, Loss: 0.5667
# Epoch 3, Batch 230, Loss: 0.5535
# Epoch 3, Batch 240, Loss: 0.4876
# Epoch 3, Batch 250, Loss: 0.5401
# Epoch 3, Batch 260, Loss: 0.4624
# Epoch 3, Batch 270, Loss: 0.6156
# Epoch 3: Train Acc: 71.03% (Spam: 94.30%) | Test Acc: 72.11% (Spam: 96.67%)

# %% [markdown]
# **Question 12 (optional)**: Now test the model *on your own text*.

# %%
def classify_text(text, model, tokenizer, device, max_length=120, pad_token_id=50256):
    model.eval()
    
    # Encode the text
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    
    # Pad/Truncate 
    # (Matches the logic in SpamDataset so the model sees familiar input structures)
    encoded = encoded[:max_length]
    pad_len = max_length - len(encoded)
    encoded += [pad_token_id] * pad_len

    # Create tensor and add batch dimension
    encoded_tensor = torch.tensor(encoded).unsqueeze(0).to(device) # Shape: [1, max_length]

    # Get prediction
    with torch.no_grad():
        logits = model(encoded_tensor)[:, -1, :] # Logits for the last token
        predicted_label = torch.argmax(logits, dim=-1).item()

    return "SPAM" if predicted_label == 1 else "NOT SPAM"

# --- TODO: Test the model ---

text_1 = (
    "Hello, I am the Prince of Nigeria. I am currently stuck abroad and I can't access my liquidity. "
    "If you can help by sending an advance of $2,500, I will repay you $50,000 as soon as my funds are released. "
    "Please reply quickly with your bank details."
)

text_2 = (
    "Hey, just wanted to check in and see if you're coming to the meeting tomorrow. Let me know!"
)

print(f"Text 1: {text_1} -> {classify_text(text_1, model, tokenizer, device)}")
print(f"Text 2: {text_2} -> {classify_text(text_2, model, tokenizer, device)}")
# Out:
# Text 1: Hello, I am the Prince of Nigeria. I am currently stuck abroad and I can't access my liquidity. If you can help by sending an advance of $2,500, I will repay you $50,000 as soon as my funds are released. Please reply quickly with your bank details. -> SPAM
# Text 2: Hey, just wanted to check in and see if you're coming to the meeting tomorrow. Let me know! -> NOT SPAM

# %% [markdown]
# ---
